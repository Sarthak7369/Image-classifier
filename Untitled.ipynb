# %%
pip install tensorflow opencv-python matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- --------------
# absl-py                      2.1.0
# altair                       5.5.0
# anyio                        4.6.2.post1
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        24.2.0
# babel                        2.16.0
# beautifulsoup4               4.12.3
# bleach                       6.2.0
# blinker                      1.9.0
# cachetools                   5.5.0
# certifi                      2024.8.30
# cffi                         1.17.1
# charset-normalizer           3.4.0
# click                        8.1.8
# colorama                     0.4.6
# comm                         0.2.2
# contourpy                    1.3.1
# cycler                       0.12.1
# debugpy                      1.8.9
# ...

# %%
import tensorflow as tf
import os

# %%
os.listdir('classfier')
# Out:
# ['happy', 'sad']

# %%
gpus = tf.config.experimental.list_physical_devices('CPU')

# %%
len(gpus)
# Out:
# 1

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)

# %%
import cv2 
import imghdr
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_12584\4067517781.py:2: DeprecationWarning: 'imghdr' is deprecated and slated for removal in Python 3.13
#   import imghdr

# %%
data_dir ='classfier'

# %%
os.listdir(os.path.join(data_dir,'happy'))
# Out:
# ['05-12-21-happy-people.jpg',
#  '170404-happy-workers-feature.jpg',
#  '220px-Happy_People_A_Year_in_the_Taiga_poster.jpg',
#  '360_F_484873483_hg1ofIdXbMha5lKEDG3hJBrwKh1oikTq.jpg',
#  '360_F_709672486_C7eaa5uLXe7qjYwuX0BvPeaUSemlVzpZ.jpg',
#  '4239f3d51d092f69d529f372a37b4601-1024x341.jpg',
#  '7-principles-of-successful-and-happy-people.png',
#  'A_Sep20_14_1189155141.jpg',
#  'business-people-succesful-celebrating-group-successful-39416686-800x500.jpg',
#  'celebrating-chess-6753651837110594.4-shsdrk.png',
#  'friends-happy-190821-1490x838.jpg',
#  'getty_152414899_97046097045006_68075.jpg',
#  'getty_478389113_970647970450091_99776.jpg',
#  'getty_505175324_2000131020009280246_158016.jpg',
#  'goup-happy-people-group-jumping-isolated-white-background-35581971.jpg',
#  'goup-happy-people-group-jumping-isolated-white-background-35582232.jpg',
#  'group-young-happy-people-with-their-hands-up_369728-62.jpg',
#  'hand-drawn-happy-friends-jumping_23-2149095224.jpg',
# ...

# %%
image_exts =['jpeg','jpg','bmp','png']

# %%
image_exts
# Out:
# ['jpeg', 'jpg', 'bmp', 'png']

# %%
tf.data.Dataset??
# Out:
# Init signature: tf.data.Dataset(variant_tensor)
# Source:
# @tf_export("data.Dataset", v1=[])
# class DatasetV2(
#     collections_abc.Iterable,
#     tracking_base.Trackable,
#     composite_tensor.CompositeTensor,
#     data_types.DatasetV2,
#     metaclass=abc.ABCMeta):
#   """Represents a potentially large set of elements.
#
#   The `tf.data.Dataset` API supports writing descriptive and efficient input
#   pipelines. `Dataset` usage follows a common pattern:
#
#   1. Create a source dataset from your input data.
#   2. Apply dataset transformations to preprocess the data.
#   3. Iterate over the dataset and process the elements.
#
#   Iteration happens in a streaming fashion, so the full dataset does not need to
#   fit into memory.
#
#   Source Datasets:
#
#   The simplest way to create a dataset is to create it from a python `list`:
#
#   >>> dataset = tf.data.Dataset.from_tensor_slices([1, 2, 3])
#   >>> for element in dataset:
#   ...   print(element)
# ...

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        image_path = os.path.join(data_dir, image_class, image)
        try: 
            img = cv2.imread(image_path)
            tip = imghdr.what(image_path)
            if tip not in image_exts: 
                print('Image not in ext list {}'.format(image_path))
                os.remove(image_path)
        except Exception as e: 
            print('Issue with image {}'.format(image_path))
            # os.remove(image_path)

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
classfier= tf.keras.utils.image_dataset_from_directory('classfier')
# Out:
# Found 110 files belonging to 2 classes.

# %%
classfier_iterator = classfier.as_numpy_iterator()

# %%
batch = classfier_iterator.next()

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %%
#preprocess data
classfier= classfier.map(lambda x,y: (x/255, y))

# %%
classfier.as_numpy_iterator().next()
# Out:
# (array([[[[7.16567114e-02, 4.53086719e-02, 6.46063127e-03],
#           [1.60150498e-01, 8.83367807e-02, 4.51995246e-02],
#           [2.44050622e-01, 1.30080044e-01, 8.51045474e-02],
#           ...,
#           [1.17647061e-02, 1.17647061e-02, 3.92156886e-03],
#           [1.17647061e-02, 1.17647061e-02, 3.92156886e-03],
#           [4.64345887e-03, 4.64345887e-03, 0.00000000e+00]],
#
#          [[6.91176504e-02, 4.27696072e-02, 3.92156886e-03],
#           [1.50000006e-01, 7.81862736e-02, 3.98284309e-02],
#           [2.44441256e-01, 1.33009732e-01, 8.91544148e-02],
#           ...,
#           [1.41544119e-02, 1.41544119e-02, 6.31127460e-03],
#           [1.41544119e-02, 1.41544119e-02, 6.31127460e-03],
#           [7.69952498e-03, 7.69952498e-03, 0.00000000e+00]],
#
#          [[7.02205896e-02, 4.27696072e-02, 3.55392159e-03],
#           [1.36213228e-01, 7.00367615e-02, 3.19240205e-02],
#           [2.39738435e-01, 1.31862745e-01, 9.25245062e-02],
#           ...,
# ...

# %%
#Split Data
train_size = int(len(classfier)*.7)
val_size = int(len(classfier)*.2)+1
test_size = int(len(classfier)*.1)+1

# %%
train_size+val_size+test_size
# Out:
# 4

# %%
train = classfier.take(train_size)
val = classfier.skip(train_size).take(val_size)
test =classfier.skip(train_size+val_size).take(test_size)

# %%
train
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
len(test)
# Out:
# 1

# %%
len(train)
# Out:
# 2

# %%
len(val)
# Out:
# 1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 254, 254, 16)   │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 127, 127, 16)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 125, 125, 32)   │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 62, 62, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 60, 60, 16)     │         4,624 │
# ...

# %%
#7. Train
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.6667 - loss: 0.7657 - val_accuracy: 0.6875 - val_loss: 0.6534
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.8021 - loss: 0.6415 - val_accuracy: 0.6562 - val_loss: 0.6310
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.7083 - loss: 0.6209 - val_accuracy: 0.6562 - val_loss: 0.5996
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 1s/step - accuracy: 0.6771 - loss: 0.6295 - val_accuracy: 0.6562 - val_loss: 0.5626
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.7083 - loss: 0.5097 - val_accuracy: 0.8125 - val_loss: 0.5739
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.7812 - loss: 0.5223 - val_accuracy: 0.7812 - val_loss: 0.5098
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 1s/step - accuracy: 0.7812 - loss: 0.4973 - val_accuracy: 0.7188 - val_loss: 0.4702
# Epoch 8/20
# ...

# %%
#8. Plot Performance
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')

if 'val_loss' in hist.history:
    plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
else:
    print("Warning: 'val_loss' not found in history.")

fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
print(hist.history.keys())
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
print(val)
# Out:
# <_TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
#9. Evaluate
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step

# %%
print(f'precision:{+pre.result().numpy()}, Recall :{re.result().numpy()},Accuracy :{ acc.result().numpy()}')
# Out:
# precision:1.0, Recall :1.0,Accuracy :1.0

# %%
import cv2

# %%
img = cv2.imread('sadtest.jpg')
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
plt.show()

# %%
resize = tf.image.resize(img, (256,256))
plt.imshow(resize.numpy().astype(int))
plt.show()

# %% [raw]
# resize

# %% [raw]
# np.expand_dims(resize,0).shape

# %%
resize.shape
# Out:
# TensorShape([256, 256, 3])

# %%
np.expand_dims(resize,0).shape
# Out:
# (1, 256, 256, 3)

# %%
yhat = model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step

# %%
yhat
# Out:
# array([[0.9972682]], dtype=float32)

# %%
if yhat >= 0.99: 
    print(f'Predicted class is Sad')
else:
    print(f'Predicted class is Happy')
# Out:
# Predicted class is Sad

# %%
#11. Save the Model
from tensorflow.keras.models import load_model

# %%
model.save(os.path.join('models','happysadmodel.h5'))
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
os.path.join('models','happysadmodel.h5')
# Out:
# 'models\\happysadmodel.h5'

# %%
new_model=load_model(os.path.join('models','happysadmodel.h5'))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
yhatnew=new_model.predict(np.expand_dims(resize/255, 0))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
